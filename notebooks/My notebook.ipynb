# %% [markdown]
# ### Add configuration

# %%
# %run ./includes/configuration

# %% [markdown]
# ### Cleaning previous data to consistency

# %%
dbutils.fs.rm(raw_path, True)
dbutils.fs.rm(bronze_path, True)
dbutils.fs.rm(silver_path, True)
dbutils.fs.rm(gold_path, True)
dbutils.fs.rm(checkpoint_path, True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[247]: True</div>

# %% [markdown]
# ### Create stream

# %%
raw_df = (
  spark.readStream.format("cloudFiles")
  .option("cloudFiles.partitionColumns", "year, month, day")
  .option("cloudFiles.format", "parquet")
  .option("cloudFiles.includeExistingFiles", True)
  .option("cloudFiles.maxFilesPerTrigger", 10)
  .option("cloudFiles.maxBytesPerTrigger", "10m")
  .schema(raw_data_schema)
  .load(raw_data_dir)
)
display(raw_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>address</th><th>avg_tmpr_c</th><th>avg_tmpr_f</th><th>city</th><th>country</th><th>geoHash</th><th>id</th><th>latitude</th><th>longitude</th><th>name</th><th>wthr_date</th><th>year</th><th>month</th><th>day</th></tr></thead><tbody><tr><td>Homewood Suites - Mall of America</td><td>15.9</td><td>60.7</td><td>Minneapolis</td><td>US</td><td>9zvx</td><td>1202590842885</td><td>44.85201</td><td>-93.23993</td><td>2261 Killebrew Dr</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Little Belt Inn Neihart</td><td>10.8</td><td>51.5</td><td>Neihart</td><td>US</td><td>c837</td><td>1571958030336</td><td>46.933598</td><td>-110.735886</td><td>316 N Main St</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Great American Inn Suites</td><td>16.6</td><td>61.8</td><td>Devils Lake</td><td>US</td><td>cb99</td><td>944892805127</td><td>48.10113</td><td>-98.84847</td><td>1116 Highway 2 E</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Pine Needles Golf Course</td><td>20.9</td><td>69.6</td><td>Southern Pines</td><td>US</td><td>dnr8</td><td>1460288880641</td><td>35.197103</td><td>-79.392412</td><td>1005 Midland Rd</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Microtel Inn By Wyndham Southern Pines</td><td>20.9</td><td>69.6</td><td>Southern Pines</td><td>US</td><td>dnr8</td><td>197568495620</td><td>35.159924</td><td>-79.410489</td><td>205 Windstar Pl</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Super 8 Blackwell Ok</td><td>18.6</td><td>65.4</td><td>Blackwell</td><td>US</td><td>9ydc</td><td>730144440325</td><td>36.8115</td><td>-97.29803</td><td>1014 W Doolin Ave</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Clarion Suites Philadelphia</td><td>15.4</td><td>59.7</td><td>Philadelphia</td><td>US</td><td>dr4e</td><td>1151051235333</td><td>39.95546</td><td>-75.15647</td><td>1010 Race St</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Holiday Inn</td><td>15.4</td><td>59.7</td><td>Philadelphia</td><td>US</td><td>dr4e</td><td>609885356033</td><td>39.907322</td><td>-75.1502</td><td>10 Packer Ave</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Cambria Hotel & Suites</td><td>15.7</td><td>60.2</td><td>Roanoke</td><td>US</td><td>dnx5</td><td>1305670057989</td><td>37.256149</td><td>-79.947005</td><td>301 Reserve Ave</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Hampton Inn Roanoke/salem</td><td>15.7</td><td>60.2</td><td>Salem</td><td>US</td><td>dnx5</td><td>1331439861763</td><td>37.265157</td><td>-80.03187</td><td>1886 Electric Rd</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Busy B Ranch</td><td>14.9</td><td>58.8</td><td>Jefferson</td><td>US</td><td>dp8u</td><td>455266533383</td><td>43.00556</td><td>-88.80733</td><td>1100 W Prospect Rd</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Fairfield Inn and Suites By Marriott Plainville</td><td>11.3</td><td>52.3</td><td>Plainville</td><td>US</td><td>drkj</td><td>1417339207683</td><td>41.672491</td><td>-72.837151</td><td>400 New Britain Ave</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Innisbrook</td><td>26.4</td><td>79.5</td><td>Palm Harbor</td><td>US</td><td>dhvp</td><td>455266533382</td><td>28.10667</td><td>-82.739915</td><td>36750 Us Highway 19 N</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Vista Hotel On Lake Tarpon</td><td>26.4</td><td>79.5</td><td>Palm Harbor</td><td>US</td><td>dhvp</td><td>111669149697</td><td>28.115091</td><td>-82.739762</td><td>37611 Us Highway 19 N</td><td>2016-10-01</td><td>2016</td><td>10</td><td>01</td></tr><tr><td>Comfort Suites</td><td>14.8</td><td>58.7</td><td>Springfield</td><td>US</td><td>dph6</td><td>704374636547</td><td>39.89509</td><td>-83.81486</td><td>121 Raydo Cir< ...

# %% [markdown]
# ### Create Bronze stream from raw data stream

# %%
from pyspark.sql.functions import lit, current_timestamp

bronze_stream = (
    raw_df.select(
        "*", 
        lit("bd201stacc/m13sparkstreaming").alias("datasource"),
        current_timestamp().alias("ingesttime")
    )
    .writeStream.format("delta")
    .outputMode("append")
    .option("checkpointLocation", bronze_checkpoint)
    .partitionBy("wthr_date")
    .queryName("write_raw_to_bronze")
    .start(bronze_path)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Check stream status

# %%
bronze_stream.status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[250]: {&#39;message&#39;: &#39;Processing new data&#39;,
#  &#39;isDataAvailable&#39;: True,
#  &#39;isTriggerActive&#39;: True}</div>

# %% [markdown]
# ### Create Delta table

# %%
spark.sql(f"DROP TABLE IF EXISTS hotel_weather_silver")
spark.sql(f"""
CREATE TABLE `hotel_weather_silver` ( 
    `wthr_date` STRING, 
    `country` STRING, 
    `city` STRING, 
    `num_distinct_hotels` BIGINT, 
    `avg_tmpr` DOUBLE, 
    `max_tmpr` DOUBLE, 
    `min_tmpr` DOUBLE) 
    USING delta PARTITIONED BY (wthr_date) 
    LOCATION '{silver_path}'
""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[251]: DataFrame[]</div>

# %%
from delta.tables import DeltaTable

silver_table = DeltaTable.forName(spark, "hotel_weather_silver")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Task 1. Using Spark calculate in Databricks Notebooks for each city each day:
#
#     * Number of distinct hotels in the city.
#     * Average/max/min temperature in the city.
#
# Note. There is no function Distinct on streaming DF. Need to use approx_count_distinct()

# %%
from pyspark.sql.functions import approx_count_distinct, avg, max, min, round

silver_stream_df = (
  spark.readStream
  .format("delta")
  .load(bronze_path)
  .groupBy("wthr_date", "country", "city")
  .agg(
    approx_count_distinct("id", 0.03).alias("num_distinct_hotels"),
    round(avg("avg_tmpr_c"), 1).alias("avg_tmpr"),
    max("avg_tmpr_c").alias("max_tmpr"),
    min("avg_tmpr_c").alias("min_tmpr"))
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Update silver table by batches

# %%
def upsert_to_delta(micro_batch_df, batch_id):
  (silver_table.alias("t").merge(micro_batch_df.alias("s"), "s.wthr_date = t.wthr_date AND s.country = t.country AND s.city = t.city")
    .whenMatchedUpdateAll()
    .whenNotMatchedInsertAll()
    .execute())

(silver_stream_df.writeStream
  .format("delta")
  .foreachBatch(upsert_to_delta)
  .outputMode("update")
  .option("checkpointLocation", silver_checkpoint) 
  .start()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[254]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7ff5b3aa1160&gt;</div>

# %%
silver_stream_df.explain(True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Parsed Logical Plan ==
# &#39;Aggregate [&#39;wthr_date, &#39;country, &#39;city], [&#39;wthr_date, &#39;country, &#39;city, approx_count_distinct(&#39;id, 0.03, 0, 0) AS num_distinct_hotels#755183, round(avg(&#39;avg_tmpr_c), 1) AS avg_tmpr#755185, max(&#39;avg_tmpr_c) AS max_tmpr#755208, min(&#39;avg_tmpr_c) AS min_tmpr#755231]
# +- StreamingRelation DataSource(org.apache.spark.sql.SparkSession@78f29141,delta,List(),None,List(),None,Map(path -&gt; /mnt/data/bronze/),None), tahoe, [address#754724, avg_tmpr_c#754725, avg_tmpr_f#754726, city#754727, country#754728, geoHash#754729, id#754730, latitude#754731, longitude#754732, name#754733, wthr_date#754734, year#754735, month#754736, day#754737, datasource#754738, ingesttime#754739]
#
# == Analyzed Logical Plan ==
# wthr_date: string, country: string, city: string, num_distinct_hotels: bigint, avg_tmpr: double, max_tmpr: double, min_tmpr: double
# Aggregate [wthr_date#754734, country#754728, city#754727], [wthr_date#754734, country#754728, city#754727, approx_count_distinct(id#754730, 0.03, 0, 0) AS num_distinct_hotels#755183L, round(avg(avg_tmpr_c#754725), 1) AS avg_tmpr#755185, max(avg_tmpr_c#754725) AS max_tmpr#755208, min(avg_tmpr_c#754725) AS min_tmpr#755231]
# +- StreamingRelation DataSource(org.apache.spark.sql.SparkSession@78f29141,delta,List(),None,List(),None,Map(path -&gt; /mnt/data/bronze/),None), tahoe, [address#754724, avg_tmpr_c#754725, avg_tmpr_f#754726, city#754727, country#754728, geoHash#754729, id#754730, latitude#754731, longitude#754732, name#754733, wthr_date#754734, year#754735, month#754736, day#754737, datasource#754738, ingesttime#754739]
#
# == Optimized Logical Plan ==
# Aggregate [wthr_date#754734, country#754728, city#754727], [wthr_date#754734, country#754728, city#754727, approx_count_distinct(id#754730, 0.03) AS num_distinct_hotels#755183L, round(avg(avg_tmpr_c#754725), 1) AS avg_tmpr#755185, max(avg_tmpr_c#754725) AS max_tmpr#755208, min(avg_tmpr_c#754725) AS min_tmpr#755231]
# +- Project [avg_tmpr_c#754725, city#754727, country#754728, id#754730, wthr_date#754734]
#    +- StreamingRelation DataSource(org.apache.spark.sql.SparkSession@78f29141,delta,List(),None,List(),None,Map(path -&gt; /mnt/data/bronze/),None), tahoe, [address#754724, avg_tmpr_c#754725, avg_tmpr_f#754726, city#754727, country#754728, geoHash#754729, id#754730, latitude#754731, longitude#754732, name#754733, wthr_date#754734, year#754735, month#754736, day#754737, datasource#754738, ingesttime#754739]
#
# == Physical Plan ==
# *(4) HashAggregate(keys=[wthr_date#754734, country#754728, city#754727], functions=[finalmerge_approx_count_distinct(merge buffer#763356) AS approx_count_distinct(id#754730, 0.03)#755182L, finalmerge_avg(merge sum#763348, count#763349L) AS avg(avg_tmpr_c#754725)#755184, finalmerge_max(merge max#763351) AS max(avg_tmpr_c#754725)#755207, finalmerge_min(merge min#763353) AS min(avg_tmpr_c#754725)#755230], output=[wthr_date#754734, country#754728, city#754727, num_distinct_hotels#755183L, avg_tmpr#755185, max_tmpr#755208, min_tmpr#755231])
# +- StateStoreSave [wthr_date#754734, country#754728, city#754727], state info [ checkpoint = &lt;unknown&gt;, runId = 519a1e46-4a88-4804-925d-f7ed244de3b3, opId = 0, ver = 0, numPartitions = 200], Append, 0, 2
#    +- *(3) HashAggregate(keys=[wthr_date#754734, country#754728, city#754727], functions=[merge_approx_count_distinct(merge buffer#763356) AS buffer#763356, merge_avg(merge sum#763348, count#763349L) AS (sum#763348, count#763349L), merge_max(merge max#763351) AS max#763351, merge_min(merge min#763353) AS min#763353], output=[wthr_date#754734, country#754728, city#754727, buffer#763356, sum#763348, count#763349L, max#763351, min#763353])
#       +- StateStoreRestore [wthr_date#754734, country#754728, city#754727], state info [ checkpoint = &lt;unknown&gt;, runId = 519a1e46-4a88-4804-925d-f7ed244de3b3, opId = 0, ver = 0, numPartitions = 200], 2
#          +- *(2) HashAggregate(keys=[wthr_date#754734, country#754728, city#754727], functions=[merge_approx_count_distinct(merge buffer#763356) AS buffer#763356, merge_avg(merge sum#763348, count#763349L) AS (sum#763348, count#763349L), merge_max(merge max#763351) AS max#763351, merge_min(merge min#763353) AS min#763353], output=[wthr_date#754734, country#754728, city#754727, buffer#763356, sum#763348, count#763349L, max#763351, min#763353])
#             +- Exchange hashpartitioning(wthr_date#754734, country#754728, city#754727, 200), ENSURE_REQUIREMENTS, [id=#370581]
#                +- *(1) HashAggregate(keys=[wthr_date#754734, country#754728, city#754727], functions=[partial_approx_count_distinct(id#754730, 0.03) AS buffer#763356, partial_avg(avg_tmpr_c#754725) AS (sum#763348, count#763349L), partial_max(avg_tmpr_c#754725) AS max#763351, partial_min(avg_tmpr_c#754725) AS min#763353], output=[wthr_date#754734, country#754728, city#754727, buffer#763356, sum#763348, count#763349L, max#763351, min#763353])
#                   +- *(1) Project [avg_tmpr_c#754725, city#754727, country#754728, id#754730, wthr_date#754734]
#                      +- StreamingRelation tahoe, [address#754724, avg_tmpr_c#754725, avg_tmpr_f#754726, city#754727, country#754728, geoHash#754729, id#754730, latitude#754731, longitude#754732, name#754733, wthr_date#754734, year#754735, month#754736, day#754737, datasource#754738, ingesttime#754739]
#
# </div>

# %%
dbutils.fs.ls(silver_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[257]: [FileInfo(path=&#39;dbfs:/mnt/data/silver/_delta_log/&#39;, name=&#39;_delta_log/&#39;, size=0)]</div>

# %% [markdown]
# ### Task 2. Visualize incoming data in Databricks Notebook for 10 biggest cities (the biggest number of hotels in the city, one chart for one city):
#
#     * X-axis: date (date of observation).
#     * Y-axis: number of distinct hotels, average/max/min temperature.

# %%
from pyspark.sql.functions import *
from pyspark.sql import *
 
window_func = Window.partitionBy("wthr_date").orderBy(desc("num_distinct_hotels"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.types import IntegerType

top_ten_biggest_cities = (silver_table.toDF()
  .select("wthr_date", "country", "city", "num_distinct_hotels", "avg_tmpr", "max_tmpr", "min_tmpr", row_number().over(window_func).cast(IntegerType()).alias("rnum"))
  .filter(col("rnum") <= 10)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(top_ten_biggest_cities)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>wthr_date</th><th>country</th><th>city</th><th>num_distinct_hotels</th><th>avg_tmpr</th><th>max_tmpr</th><th>min_tmpr</th><th>rnum</th></tr></thead><tbody><tr><td>2016-10-01</td><td>US</td><td>Albuquerque</td><td>4</td><td>18.9</td><td>18.9</td><td>18.9</td><td>1</td></tr><tr><td>2016-10-01</td><td>US</td><td>Virginia Beach</td><td>3</td><td>24.7</td><td>24.7</td><td>24.7</td><td>2</td></tr><tr><td>2016-10-01</td><td>US</td><td>Enterprise</td><td>2</td><td>3.8</td><td>3.8</td><td>3.8</td><td>3</td></tr><tr><td>2016-10-01</td><td>US</td><td>Mobile</td><td>2</td><td>20.5</td><td>20.5</td><td>20.5</td><td>4</td></tr><tr><td>2016-10-01</td><td>US</td><td>Fryeburg</td><td>2</td><td>11.2</td><td>11.2</td><td>11.2</td><td>5</td></tr><tr><td>2016-10-01</td><td>US</td><td>Lancaster</td><td>2</td><td>14.0</td><td>14.0</td><td>14.0</td><td>6</td></tr><tr><td>2016-10-01</td><td>US</td><td>Southern Pines</td><td>2</td><td>20.9</td><td>20.9</td><td>20.9</td><td>7</td></tr><tr><td>2016-10-01</td><td>US</td><td>Rockford</td><td>2</td><td>15.8</td><td